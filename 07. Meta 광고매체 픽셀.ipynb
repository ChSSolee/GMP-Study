# %% [markdown]
# # 07. Meta 광고매체 픽셀 설치
#
# <br>
#
# ### 픽셀 신규 생성의 경우
#
# <br>
#
# #### 01. Meta 이벤트 관리자 접속
#
# <img src='image/GTM/070101.jpg' width=600>
#
# <br>
#
# #### 02. 픽셀 발급
#
# - 데이터 소스 연결
#
# <img src='image/GTM/070102.jpg' width=600>
#
# <br>
#
# - 데이터 세트 생성
#     - 브랜드 이름으로 입력하는 것이 일반적
#
# <img src='image/GTM//070103.jpg' width=400>
#
# <br>
#
# - 웹 사이트 추가 $rightarrow$ 설정 '직접 해보기'
#
# <img src='image/GTM//070104.jpg' width=400>
#
#
# <img src='image/GTM//070105.jpg' width=400>
#
# <img src='image/GTM//070106.jpg' width=400>
#
#
# <img src='image/GTM//070107.jpg' width=400>
#
# <img src='image/GTM//070108.jpg' width=600>
#
# <br>

# %% [markdown]
# ### 기존 픽셀에 추가하는 경우
#
# <br>
#
# #### 01.
#
# <img src='image/GTM/070109.jpg' width=500>
#
# <img src='image/GTM/070110.jpg' width=500>
#
# <br>
#
# #### 02. 코드 복사
#
# <img src='image/GTM/070111.jpg' width=500>
#
# <br>
#
# <hr>
#
# <br>
#
# ## GTM 태그 생성
# - **맞춤 HTML에 복사한 픽셀 코드 붙여넣기** 혹은 **템플릿 활용**
#
# <br>
#
# ### 맞춤 HTML 활용
# - 메타 픽셀 삽입 후 제출
# - **기본 메타 픽셀은, 메타의 'PageView'이벤트 스크립트**
#
# <img src='image/GTM/070112.jpg' width=500>

# %% [markdown]
# <br>
#
# ### Meta 픽셀 템플릿 활용
#
# <br>
#
# #### 01. 템플릿 불러오기
#
# <img src='image/GTM/070113.jpg' width=500>
#
# <br>
#
# #### 02. 태그 생성
#
# <img src='image/GTM/070114.jpg' width=400>
#
# <br>
#
# <img src='image/GTM/070115.jpg' width=600>

# %% [markdown]
# <br>
#
# <hr>
#
# <br>
#
# ## 설치후 확인
#
# <img src='image/GTM/070116.jpg' width=600>
#
# <br>
#
# <hr>
#
# ## 이벤트 스크립트
# - 이벤트 추가 $\rightarrow$ '새 통합 추가' $\rightarrow$ 'Meta 픽셀'
#
# <img src='image/GTM/070117.jpg' width=600>
#
# <br>
#
# <img src='image/GTM/070118.jpg' width=300>
#
# <img src='image/GTM/070119.jpg' width=300>

# %% [markdown]
# <br>
#
# ### Meta 픽셀 전환 추적
# - https://developers.facebook.com/docs/meta-pixel/implementation/conversion-tracking?locale=ko_KR
#
# <br>
#
# #### 표준 이벤트
# - https://developers.facebook.com/docs/meta-pixel/reference#standard-events
# - 메타 픽셀 템플릿 'Standard'에서 확인/설정 가능
#
# <img src='image/GTM/070120.jpg' width=300>
#
# <br>
#
# #### 커스텀 이벤트
#
# <br>
#
# - **변수 생성 : 픽셀 데이터 세트 ID**
#
# <image src='image/GTM/070122.jpg' width=400>
#
# <br>
#
# <image src='image/GTM/070123.png' width=400>
#
#
# <br>
#
# - 메타 픽셀 템플릿에서 'Custom' 이벤트 생성
#     - 트리거 생성/적용은 기존 GA와 동일
#
# <img src='image/GTM/070121.png' width=500>

# %% [markdown]
# <br>
#
# <hr>
#
# <br>
#
# ## Meta 픽셀 - 이벤트 매개변수
# - **Meta의 표준 이벤트는, 이벤트 매개변수의 속성명 규칙이 존재**
#     - https://developers.facebook.com/docs/meta-pixel/reference#standard-events
#
#
# <img src='image/GTM/070124.jpg' width=600>
#
# <br>
#
# <hr>
