# %% [markdown]
# # 09. 카카오 광고매체 픽셀
#
# <br>
#
# ## 픽셀 생성
# - https://kakaobusiness.gitbook.io/main/tool/pixel-sdk/install
#
# <br>
#
# - 비즈도구 $\rightarrow$ '픽셀 & SDK'
#
# <img src='image/GTM/0901.jpg' width=500>
#
# <br>
#
# - 생성
#
# <img src='image/GTM/0902.jpg' width=600>
#
# <br>
#
# - 픽셀 ID 복사
#
# <img src='image/GTM/0904.jpg' width=600>

# %% [markdown]
# <br>
#
# ## 태그 생성
#
# <br>
#
# ####  픽셀 ID 변수 생성
# - 복사한 픽셀 ID
#
# <img src='image/GTM/0905.png' width=500>
#
#
# <br>
#
# ### 태그 템플릿 불러오기 및 생성
#
# <img src='image/GTM/0903.jpg' width=500>
#
# <br>
#
# - 이벤트 태그 생성
#     - 트리거 생성/적용는 GA이벤트와 동일
#
# <img src='image/GTM/0906.jpg' width=500>
#
# <br>
#
# <hr>
