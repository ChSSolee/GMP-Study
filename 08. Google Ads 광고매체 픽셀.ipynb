# %% [markdown]
# # 08. Google Ads 광고매체 픽셀
# - **Google Ads는 전체 웹 사이트 스크립트, 이벤트 스크립트 2개의 설정 필요**
#
# <br>
#
# ## Google Ads 태그
# - 도구 $\rightarrow$ 잠재고객 관리자 $\rightarrow$ Google Ads 태그
#
# <br>
#
# ### 01. 웹 사이트 태그
#
# <br>
#
# #### 리마케팅 태그
#
# <img src='image/GTM/0801.jpg' width=500>
#
#
# <br>
#
# #### 웹 사이트에 태그 설치
#
# <img src='image/GTM/0802.jpg' width=500>
#
# <img src='image/GTM/0803.jpg' width=500>

# %% [markdown]
# <br>
#
# #### '전환 ID' 복사 후, GTM내 태그 생성
#     - 'Google Ads 리마케팅'
#
# <img src='image/GTM/0804.jpg' width=500>
#
# <br>
#
# <img src='image/GTM/0805.jpg' width=500>

# %% [markdown]
# <br>
#
# <hr>
#
# <br>
#
# ### 이벤트 태그
# - 목표 $\rightarrow$ 기여 분석 $\rightarrow$ 전환 액션 만들기 $\rightarrow$
#
# <img src='image/GTM/0806.jpg' width=500>
#
# <br>
#
# <img src='image/GTM/0807.jpg' width=500>
#
# <br>
#
# <img src='image/GTM/0808.png' width=500>
#
# <br>
#
# <img src='image/GTM/0809.jpg' width=500>
#
# <br>
#
# <img src='image/GTM/0810.jpg' width=500>
#
# <br>
#
# - '전환 ID' 및 각 '이벤트 전환 라벨' 복사
#
# <img src='image/GTM/0811.jpg' width=500>

# %% [markdown]
# <br>
#
# #### GTM내 전환 추적 태그 생성
#
# <img src='image/GTM/0812.jpg' width=400>
#
# <br>
#
# - 복사한 전환 ID 및 라벨 입력
#
# <img src='image/GTM/0813.jpg' width=600>
#
# <br>
#
# <hr>
#
# <br>
#
# ## 데이터 확인
#
# <br>
#
# ### Google Ads -  잠재고객 관리자
#
# <img src='image/GTM/0814.jpg' width=600>
#
#
# <br>
#
# ### Google Analytics 연결
#
# <img src='image/GTM/0815.jpg' width=600>
#
# <br>
#
# <hr>
